# %%
import gym 
from gym import Env
from gym.spaces import Discrete, Box, Dict, Tuple, MultiBinary, MultiDiscrete 
import numpy as np
import random
import os
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.evaluation import evaluate_policy

# %%
class ShowerEnv(Env):
    def __init__(self):
        self.action_space = Discrete(3)
        self.observation_space = Box(low=np.array([0]), high=np.array([100]))
        self.state = 38 + random.randint(-3, 3)
        self.shower_length = 60
        
    
    def step(self, action):
        # Apply action
        # 0 -1 = -1 temperature
        # 1 -1 = 0 
        # 2 -1 = 1 temperature 
        self.state += action -1 
        # Reduce shower length by 1 second
        self.shower_length -= 1 
        
        # Calculate reward
        if self.state >=37 and self.state <= 39: 
            reward =1 
        else: 
            reward = -1 
        
        # Check if shower is done
        if self.shower_length <= 0: 
            done = True
        else:
            done = False
        
        # Apply temperature noise
        #self.state += random.randint(-1,1)
        # Set placeholder for info
        info = {}
        
        # Return step information
        return self.state, reward, done, info

    
    def render(self):
        pass
    
    def reset(self):
        self.shower_length = 60
        self.state = np.array([38 + random.randint(-3,3)]).astype(float)        
        return self.state

# %%
env=ShowerEnv()
# Out:
# /opt/jupyterhub/anaconda/lib/python3.9/site-packages/gym/logger.py:34: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize("%s: %s" % ("WARN", msg % args), "yellow"))

# %%
env.observation_space.sample()
# Out:
# array([52.22407], dtype=float32)

# %%
env.action_space.sample()
# Out:
# 1

# %%
from stable_baselines3.common.env_checker import check_env

# %%
check_env(env, warn=True)

# %%
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# Episode:1 Score:-36
# Episode:2 Score:-26
# Episode:3 Score:-24
# Episode:4 Score:-28
# Episode:5 Score:-10

# %%
log_path = os.path.join('Training', 'Logs')

# %%
model = PPO("MlpPolicy", env, verbose=1)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# /opt/jupyterhub/anaconda/lib/python3.9/site-packages/torch/cuda/__init__.py:83: UserWarning: CUDA initialization: CUDA driver initialization failed, you might not have a CUDA gpu. (Triggered internally at  /opt/conda/conda-bld/pytorch_1659484809662/work/c10/cuda/CUDAFunctions.cpp:109.)
#   return torch._C._cuda_getDeviceCount() > 0

# %%
model.learn(total_timesteps=100000)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | -30.1    |
# | time/              |          |
# |    fps             | 1510     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -27.3       |
# | time/                   |             |
# |    fps                  | 1014        |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008668538 |
# |    clip_fraction        | 0.0386      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.000351   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.4        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.000799   |
# |    value_loss           | 55.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -24.5       |
# | time/                   |             |
# |    fps                  | 923         |
# |    iterations           | 3           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.013776954 |
# |    clip_fraction        | 0.0996      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.00079     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.9        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00876    |
# |    value_loss           | 60.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -22.6       |
# | time/                   |             |
# |    fps                  | 930         |
# |    iterations           | 4           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009622071 |
# |    clip_fraction        | 0.0204      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.000607   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.4        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00263    |
# |    value_loss           | 58.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -24.3       |
# | time/                   |             |
# |    fps                  | 926         |
# |    iterations           | 5           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.012344111 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.000746   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.4        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0141     |
# |    value_loss           | 58.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -26.4       |
# | time/                   |             |
# |    fps                  | 926         |
# |    iterations           | 6           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.008045489 |
# |    clip_fraction        | 0.00327     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 3.1e-06     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 31.2        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -7.34e-05   |
# |    value_loss           | 61.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -25.2       |
# | time/                   |             |
# |    fps                  | 908         |
# |    iterations           | 7           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.011699696 |
# |    clip_fraction        | 0.0843      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 2.53e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 37.5        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00702    |
# |    value_loss           | 70.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -25.3        |
# | time/                   |              |
# |    fps                  | 893          |
# |    iterations           | 8            |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0064669354 |
# |    clip_fraction        | 0.0631       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | -0.000136    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 30.8         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.006       |
# |    value_loss           | 72.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -26.7        |
# | time/                   |              |
# |    fps                  | 877          |
# |    iterations           | 9            |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0015433052 |
# |    clip_fraction        | 0.0227       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | -0.00359     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 27.5         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | 0.000478     |
# |    value_loss           | 62.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -25.6       |
# | time/                   |             |
# |    fps                  | 862         |
# |    iterations           | 10          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.008544525 |
# |    clip_fraction        | 0.0798      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.00151     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32.3        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00682    |
# |    value_loss           | 77.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -23.7       |
# | time/                   |             |
# |    fps                  | 858         |
# |    iterations           | 11          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.010927512 |
# |    clip_fraction        | 0.0718      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.0049      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34.5        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00269    |
# |    value_loss           | 60.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -19.4       |
# | time/                   |             |
# |    fps                  | 854         |
# |    iterations           | 12          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.005642019 |
# |    clip_fraction        | 0.0671      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | -0.0242     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.7        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00481    |
# |    value_loss           | 69.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -24         |
# | time/                   |             |
# |    fps                  | 844         |
# |    iterations           | 13          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.010432133 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.0107      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 31.6        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00906    |
# |    value_loss           | 62.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -24.6       |
# | time/                   |             |
# |    fps                  | 836         |
# |    iterations           | 14          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.009722754 |
# |    clip_fraction        | 0.0623      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.0226     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.6        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00489    |
# |    value_loss           | 52.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -28.6        |
# | time/                   |              |
# |    fps                  | 828          |
# |    iterations           | 15           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0075476975 |
# |    clip_fraction        | 0.102        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | -0.000231    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 30.5         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00471     |
# |    value_loss           | 71.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -25.3        |
# | time/                   |              |
# |    fps                  | 817          |
# |    iterations           | 16           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0045757974 |
# |    clip_fraction        | 0.0204       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | -0.0011      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 29.2         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00248     |
# |    value_loss           | 72.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -24.6       |
# | time/                   |             |
# |    fps                  | 819         |
# |    iterations           | 17          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.011079866 |
# |    clip_fraction        | 0.0297      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | -0.00697    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.1        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00257    |
# |    value_loss           | 68.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -24.4       |
# | time/                   |             |
# |    fps                  | 826         |
# |    iterations           | 18          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.015305904 |
# |    clip_fraction        | 0.0835      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | -0.00732    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.7        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00594    |
# |    value_loss           | 77.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -21.9       |
# | time/                   |             |
# |    fps                  | 832         |
# |    iterations           | 19          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.006677355 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | -0.00557    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 39.6        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00628    |
# |    value_loss           | 69          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -19.9        |
# | time/                   |              |
# |    fps                  | 832          |
# |    iterations           | 20           |
# |    time_elapsed         | 49           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0041799727 |
# |    clip_fraction        | 0.0246       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | -0.00029     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 34.1         |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.000815    |
# |    value_loss           | 72.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -17.9       |
# | time/                   |             |
# |    fps                  | 818         |
# |    iterations           | 21          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.008343885 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.00288     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.8        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0114     |
# |    value_loss           | 72.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -17.2       |
# | time/                   |             |
# |    fps                  | 808         |
# |    iterations           | 22          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.017414566 |
# |    clip_fraction        | 0.0958      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.997      |
# |    explained_variance   | -0.0109     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 38.3        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00726    |
# |    value_loss           | 71.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -16.5       |
# | time/                   |             |
# |    fps                  | 810         |
# |    iterations           | 23          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.009016264 |
# |    clip_fraction        | 0.0875      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.966      |
# |    explained_variance   | -0.00426    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30.1        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00579    |
# |    value_loss           | 69.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -14.8       |
# | time/                   |             |
# |    fps                  | 816         |
# |    iterations           | 24          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.007330117 |
# |    clip_fraction        | 0.0743      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.954      |
# |    explained_variance   | -0.0218     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 40.9        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00801    |
# |    value_loss           | 86.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -16.7        |
# | time/                   |              |
# |    fps                  | 813          |
# |    iterations           | 25           |
# |    time_elapsed         | 62           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0040748585 |
# |    clip_fraction        | 0.0256       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.957       |
# |    explained_variance   | 0.0111       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 26           |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.0016      |
# |    value_loss           | 70           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -14.2       |
# | time/                   |             |
# |    fps                  | 813         |
# |    iterations           | 26          |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.008741778 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.952      |
# |    explained_variance   | -0.047      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 35.7        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0123     |
# |    value_loss           | 66.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -11.2        |
# | time/                   |              |
# |    fps                  | 817          |
# |    iterations           | 27           |
# |    time_elapsed         | 67           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0034194025 |
# |    clip_fraction        | 0.014        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.95        |
# |    explained_variance   | 0.00385      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 32.2         |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00146     |
# |    value_loss           | 75.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -6.14        |
# | time/                   |              |
# |    fps                  | 817          |
# |    iterations           | 28           |
# |    time_elapsed         | 70           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0071158987 |
# |    clip_fraction        | 0.11         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.973       |
# |    explained_variance   | -0.00913     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 38           |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00778     |
# |    value_loss           | 72.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -11.2        |
# | time/                   |              |
# |    fps                  | 815          |
# |    iterations           | 29           |
# |    time_elapsed         | 72           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0032420629 |
# |    clip_fraction        | 0.0382       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.963       |
# |    explained_variance   | 0.0308       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 37.2         |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00132     |
# |    value_loss           | 61.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -9.4        |
# | time/                   |             |
# |    fps                  | 818         |
# |    iterations           | 30          |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.009165846 |
# |    clip_fraction        | 0.0543      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.965      |
# |    explained_variance   | 0.00778     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.2        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00107    |
# |    value_loss           | 59.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -9          |
# | time/                   |             |
# |    fps                  | 812         |
# |    iterations           | 31          |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.005472708 |
# |    clip_fraction        | 0.0955      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.949      |
# |    explained_variance   | 0.0461      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.8        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00558    |
# |    value_loss           | 61.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -1.7         |
# | time/                   |              |
# |    fps                  | 816          |
# |    iterations           | 32           |
# |    time_elapsed         | 80           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0056888047 |
# |    clip_fraction        | 0.102        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.947       |
# |    explained_variance   | -0.0628      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 24.7         |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00247     |
# |    value_loss           | 63.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 0.08        |
# | time/                   |             |
# |    fps                  | 811         |
# |    iterations           | 33          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.006708868 |
# |    clip_fraction        | 0.0885      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.907      |
# |    explained_variance   | 0.00158     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.4        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00228    |
# |    value_loss           | 70.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 0.98         |
# | time/                   |              |
# |    fps                  | 812          |
# |    iterations           | 34           |
# |    time_elapsed         | 85           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0033596568 |
# |    clip_fraction        | 0.0793       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.892       |
# |    explained_variance   | 0.00211      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 25.4         |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.000789    |
# |    value_loss           | 56.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 1.34        |
# | time/                   |             |
# |    fps                  | 813         |
# |    iterations           | 35          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.008008382 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.908      |
# |    explained_variance   | 0.0092      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.7        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0102     |
# |    value_loss           | 72.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 5.78        |
# | time/                   |             |
# |    fps                  | 811         |
# |    iterations           | 36          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.003477071 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.911      |
# |    explained_variance   | 0.0157      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.4        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0027     |
# |    value_loss           | 48.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 7.36        |
# | time/                   |             |
# |    fps                  | 811         |
# |    iterations           | 37          |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.007330459 |
# |    clip_fraction        | 0.0948      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.897      |
# |    explained_variance   | 0.0216      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.1        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00329    |
# |    value_loss           | 43.4        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 10         |
# | time/                   |            |
# |    fps                  | 809        |
# |    iterations           | 38         |
# |    time_elapsed         | 96         |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.01382351 |
# |    clip_fraction        | 0.202      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.896     |
# |    explained_variance   | 0.043      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 40.8       |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.0138    |
# |    value_loss           | 58.8       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 10.3       |
# | time/                   |            |
# |    fps                  | 809        |
# |    iterations           | 39         |
# |    time_elapsed         | 98         |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.01523236 |
# |    clip_fraction        | 0.143      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.882     |
# |    explained_variance   | -0.0475    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 25.4       |
# |    n_updates            | 380        |
# |    policy_gradient_loss | -0.000946  |
# |    value_loss           | 50.2       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 16           |
# | time/                   |              |
# |    fps                  | 807          |
# |    iterations           | 40           |
# |    time_elapsed         | 101          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0043794103 |
# |    clip_fraction        | 0.121        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.856       |
# |    explained_variance   | 0.0178       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 26.3         |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.000583    |
# |    value_loss           | 47.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 19.2        |
# | time/                   |             |
# |    fps                  | 810         |
# |    iterations           | 41          |
# |    time_elapsed         | 103         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.002825108 |
# |    clip_fraction        | 0.1         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.858      |
# |    explained_variance   | -0.0094     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.3        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | 0.000515    |
# |    value_loss           | 51.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 22          |
# | time/                   |             |
# |    fps                  | 812         |
# |    iterations           | 42          |
# |    time_elapsed         | 105         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.024949282 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.845      |
# |    explained_variance   | 0.0179      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32          |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00264    |
# |    value_loss           | 59.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 23.7        |
# | time/                   |             |
# |    fps                  | 816         |
# |    iterations           | 43          |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.009353071 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.837      |
# |    explained_variance   | -0.0448     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.1        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00479    |
# |    value_loss           | 59.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 25.1        |
# | time/                   |             |
# |    fps                  | 819         |
# |    iterations           | 44          |
# |    time_elapsed         | 109         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.009113322 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.838      |
# |    explained_variance   | 0.0786      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.1        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00718    |
# |    value_loss           | 55.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 26          |
# | time/                   |             |
# |    fps                  | 822         |
# |    iterations           | 45          |
# |    time_elapsed         | 112         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.021790672 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.849      |
# |    explained_variance   | -0.0789     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.6        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | 0.00295     |
# |    value_loss           | 59.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 27.4        |
# | time/                   |             |
# |    fps                  | 824         |
# |    iterations           | 46          |
# |    time_elapsed         | 114         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.015460894 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.834      |
# |    explained_variance   | 0.0517      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.6        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0021     |
# |    value_loss           | 61.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 27.2        |
# | time/                   |             |
# |    fps                  | 822         |
# |    iterations           | 47          |
# |    time_elapsed         | 116         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.032153673 |
# |    clip_fraction        | 0.236       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.855      |
# |    explained_variance   | 0.0619      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.6        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.01       |
# |    value_loss           | 58.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 29.3        |
# | time/                   |             |
# |    fps                  | 819         |
# |    iterations           | 48          |
# |    time_elapsed         | 119         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.023508938 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.827      |
# |    explained_variance   | 0.065       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.3        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00549    |
# |    value_loss           | 58.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 31          |
# | time/                   |             |
# |    fps                  | 822         |
# |    iterations           | 49          |
# |    time_elapsed         | 122         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.085520715 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.836      |
# |    explained_variance   | -0.0718     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 33.6        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | 0.00921     |
# |    value_loss           | 57.2        |
# -----------------------------------------
